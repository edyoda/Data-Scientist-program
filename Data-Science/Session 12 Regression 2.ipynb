# %%
import pandas as pd

# %%
air_quality_data = pd.read_excel('/home/awantik/Downloads/AirQualityUCI/AirQualityUCI.xlsx')

# %%
air_quality_data.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# 2  11.90  53.975000  0.750239
# 3  11.00  60.000000  0.786713
# 4  11.15  59.575001  0.788794

# %%
air_quality_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
# Date             9357 non-null datetime64[ns]
# Time             9357 non-null object
# CO(GT)           9357 non-null float64
# PT08.S1(CO)      9357 non-null float64
# NMHC(GT)         9357 non-null int64
# C6H6(GT)         9357 non-null float64
# PT08.S2(NMHC)    9357 non-null float64
# NOx(GT)          9357 non-null float64
# PT08.S3(NOx)     9357 non-null float64
# NO2(GT)          9357 non-null float64
# PT08.S4(NO2)     9357 non-null float64
# PT08.S5(O3)      9357 non-null float64
# T                9357 non-null float64
# RH               9357 non-null float64
# AH               9357 non-null float64
# dtypes: datetime64[ns](1), float64(12), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
target_data = air_quality_data.AH

# %%
#Not using time as feature data
feature_data = air_quality_data.drop(columns=['Date','Time','AH'])

# %%
feature_data.head()
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6      1360.00       150  11.881723        1045.50    166.0
# 1     2.0      1292.25       112   9.397165         954.75    103.0
# 2     2.2      1402.00        88   8.997817         939.25    131.0
# 3     2.2      1375.50        80   9.228796         948.25    172.0
# 4     1.6      1272.25        51   6.518224         835.50    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T         RH
# 0       1056.25    113.0       1692.00      1267.50  13.60  48.875001
# 1       1173.75     92.0       1558.75       972.25  13.30  47.700000
# 2       1140.00    114.0       1554.50      1074.00  11.90  53.975000
# 3       1092.00    122.0       1583.75      1203.25  11.00  60.000000
# 4       1205.00    116.0       1490.00      1110.00  11.15  59.575001

# %%
#Splitting the data
from sklearn.model_selection import train_test_split

# %%
trainX, testX, trainY, testY = train_test_split(feature_data,target_data)

# %%
#It's regression because target is continues
#These are different  regression algorithms
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %%
#Create empty models for these algorithms
dt = DecisionTreeRegressor()
svr = SVR()
rf = RandomForestRegressor()

# %%
dt.fit(trainX,trainY)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
testX[:2]
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 5307  -200.0       974.75      -200  7.802388          891.0   -200.0
# 370      0.7       924.50        40  2.246786          602.0     45.0
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T         RH
# 5307        813.75   -200.0        1361.0       911.00  15.800  57.625001
# 370        1398.00     59.0        1263.0       562.25   7.975  69.400000

# %%
testY[:2]
# Out:
# 5307    1.027091
# 370     0.745859
# Name: AH, dtype: float64

# %%
dt.predict(testX[:2])
# Out:
# array([1.03421801, 0.76083287])

# %%
rf.fit(trainX,trainY)
#Generate a mathematical formula & stores in rf object
# Out:
# /home/awantik/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rf.predict(testX[:2])
# Out:
# array([1.03854615, 0.74537205])

# %%
testX[:1]
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 5307  -200.0       974.75      -200  7.802388          891.0   -200.0
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T         RH
# 5307        813.75   -200.0        1361.0        911.0  15.8  57.625001

# %%
svr.fit(trainX,trainY)
# Out:
# /home/awantik/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
svr.predict(testX[:2])
# Out:
# array([0.98193981, 0.98193981])

# %%
hr_data = pd.read_csv('data-science-complete-tutorial/Data/HR_comma_sep.csv.txt')

# %%
hr_data.rename(columns={'sales':'dept'},inplace=True)

# %%
hr_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years   dept  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
target_data = hr_data.satisfaction_level

# %%
feature_data = hr_data.drop(columns=['satisfaction_level'])

# %%
feature_data.head()
# Out:
#    last_evaluation  number_project  average_montly_hours  time_spend_company  \
# 0             0.53               2                   157                   3
# 1             0.86               5                   262                   6
# 2             0.88               7                   272                   4
# 3             0.87               5                   223                   5
# 4             0.52               2                   159                   3
#
#    Work_accident  left  promotion_last_5years   dept  salary
# 0              0     1                      0  sales     low
# 1              0     1                      0  sales  medium
# 2              0     1                      0  sales  medium
# 3              0     1                      0  sales     low
# 4              0     1                      0  sales     low

# %%
#Convert categoral data into numbers

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
hr_data['dept_en'] = le.fit_transform(hr_data.dept)

# %%
hr_data.sample(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 8528                 0.98             0.62               5
# 2033                 0.75             0.56               5
# 1799                 0.38             0.50               2
# 4576                 0.97             0.60               5
# 6414                 0.92             0.49               5
# 7374                 0.51             0.86               4
# 5381                 0.79             0.83               5
# 2830                 0.84             0.92               4
# 11706                0.42             0.44               3
# 1858                 0.38             0.47               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 8528                    260                   2              1     0
# 2033                    175                   4              0     0
# 1799                    145                   3              0     1
# 4576                    133                   2              0     0
# 6414                    145                   3              0     0
# 7374                    223                   3              1     0
# 5381                    268                   3              0     0
# 2830                    274                   3              0     0
# 11706                   183                   2              0     0
# 1858                    128                   3              0     1
#
#        promotion_last_5years         dept  salary  dept_en
# 8528                       0      support     low        8
# 2033                       0      support     low        8
# 1799                       0    technical     low        9
# 4576                       0        RandD  medium        1
# 6414                       0    technical     low        9
# 7374                       0      support  medium        8
# 5381                       0    technical     low        9
# 2830                       0   management  medium        4
# 11706                      0  product_mng  medium        6
# 1858                       0        sales  medium        7

# %%
le.classes_
# Out:
# array(['IT', 'RandD', 'accounting', 'hr', 'management', 'marketing',
#        'product_mng', 'sales', 'support', 'technical'], dtype=object)

# %%
le_salary = LabelEncoder()

# %%
hr_data['salary_en'] = le_salary.fit_transform(hr_data.salary)

# %%
hr_data.sample(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 5717                 0.58             0.57               5
# 13310                0.61             0.90               2
# 14812                0.84             0.94               5
# 10335                0.14             0.43               2
# 10592                0.59             0.72               4
# 4962                 0.89             0.55               4
# 5647                 0.64             0.63               5
# 5199                 0.34             0.87               4
# 13364                0.37             0.69               2
# 2918                 0.67             0.82               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 5717                    105                   6              0     0
# 13310                   142                   3              0     0
# 14812                   222                   6              0     1
# 10335                   238                   3              0     0
# 10592                   168                   4              0     0
# 4962                    196                   2              0     0
# 5647                    105                   5              1     0
# 5199                    283                   2              0     0
# 13364                   146                   3              0     0
# 2918                    171                   2              0     0
#
#        promotion_last_5years         dept  salary  dept_en  salary_en
# 5717                       0  product_mng  medium        6          2
# 13310                      0    marketing    high        5          0
# 14812                      0  product_mng     low        6          1
# 10335                      0           hr     low        3          1
# 10592                      0   management  medium        4          2
# 4962                       0   accounting  medium        2          2
# 5647                       0        RandD     low        1          1
# 5199                       0        sales    high        7          0
# 13364                      0      support  medium        8          2
# 2918                       0        sales  medium        7          2

# %%
feature_data = hr_data.drop(columns=['salary','dept','satisfaction_level'])

# %%
feature_data.head()
# Out:
#    last_evaluation  number_project  average_montly_hours  time_spend_company  \
# 0             0.53               2                   157                   3
# 1             0.86               5                   262                   6
# 2             0.88               7                   272                   4
# 3             0.87               5                   223                   5
# 4             0.52               2                   159                   3
#
#    Work_accident  left  promotion_last_5years  dept_en  salary_en
# 0              0     1                      0        7          1
# 1              0     1                      0        7          2
# 2              0     1                      0        7          2
# 3              0     1                      0        7          1
# 4              0     1                      0        7          1

# %%
dt = DecisionTreeRegressor()

# %%
from sklearn.model_selection import train_test_split

# %%
trainX, testX, trainY, testY = train_test_split(feature_data, target_data)
